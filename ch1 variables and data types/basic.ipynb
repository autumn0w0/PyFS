# %%
print("hellow world")
# Out:
# hellow world

# %%
print(1+2)
# Out:
# 3

# %%
name = "xyz4"
age = 20
cost = 100.5
print(name, age, cost)
print("my name is", name, "my age is", age, "and my cost is", cost)
# Out:
# xyz4 20 100.5
# my name is xyz4 my age is 20 and my cost is 100.5

# %%
age2 = age + 5
print(age2)
# Out:
# 25

# %%
name = int(input("enter your name: "))
print("your name is", name)
# Out:
# your name is 1

# %%
age = str(input("enter your age: "))
print("your age is", age)
# Out:
# your age is asf
