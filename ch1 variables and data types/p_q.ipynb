# %% [markdown]
# PROGRAM TO INPUT 2 NUMBERS AND PRINT THEIR SUM

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))    
sum = num1 + num2
print("The sum of", num1, "and", num2, "is", sum)
# Out:
# The sum of 12.0 and 2.333 is 14.333

# %% [markdown]
# PROGRAM TO INPUT SIDE OF A SQUARE AND PRINT ITS AREA

# %%
l1 = float(input("Enter length of first side: "))
l2 = float(input("Enter length of second side: "))

area = l1 * l2
print("The area of the rectangle is", area, "square units")
# Out:
# The area of the rectangle is 528.96

# %% [markdown]
# WAP TO INPUT 2 FLOATING POINTS NUMBER AND PRIONT THEIR AVERAGE

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

average = (num1 + num2) / 2
print("The average of", num1, "and", num2, "is", average)
# Out:
# The average of 2.0 and 2222.45654745678 is 1112.22827372839

# %% [markdown]
# WAP TP INPUT 2 INT NUMBERS , A AND B
# PRINT TRUE IF A IS GREATER THEN OT EQUAL TO B , IF NOT PRINT FALSE

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(num1>=num2)
# Out:
# False
